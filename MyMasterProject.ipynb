# %%
#import all necessary libries
import numpy as np
import pandas as pd
import json
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_json('data.json')

# %%
df.head()
# Out:
#      agent_name                  build_id   duration  \
# 0  NO-L-7423199  Build number not defined  15.232570
# 1  NO-L-7423199  Build number not defined  34.646874
# 2  NO-L-7423199  Build number not defined  32.037125
# 3  NO-L-7423199  Build number not defined  14.489447
# 4  NO-L-7423199  Build number not defined  13.519060
#
#                                      id  numberOfAbort  numberOfErrors  \
# 0  cd207543-fe6d-413d-b86b-6e80efa642f5            0.0             0.0
# 1  111ef6e8-f462-4d10-b756-6e3bf4e6a7f4            0.0             0.0
# 2  a9ceb758-2bea-4100-af60-6a875c2865f2            1.0             1.0
# 3  763f09da-72a2-4b51-af86-d390b1533629            0.0             0.0
# 4  6e696813-76cd-44bb-8550-7fa42d25798f            0.0             0.0
#
#    numberOfPassed  numberOfWarning  run_id             start_of_test  ...  \
# 0            14.0              0.0  999999  2024-11-18 07:27:33.5955  ...
# 1            12.0              1.0  999999  2024-11-18 07:34:13.3142  ...
# 2             2.0              1.0  999999  2024-11-18 07:46:19.2557  ...
# 3            26.0              1.0  999999  2024-11-18 07:49:37.5379  ...
# 4            13.0              0.0  999999  2024-11-18 07:50:11.9302  ...
#
#   testOutcomeString test_case_id  test_case_name  \
# 0            Passed       999999  No WI assigned
# 1           Warning       999999  No WI assigned
# 2           Aborted       999999  No WI assigned
# 3           Warning       999999  No WI assigned
# 4            Passed       999999  No WI assigned
#
#                                         z_subResults  \
# 0  [{'consoleendline': 213, 'consolestartline': 0...
# 1  [{'consoleendline': 86, 'consolestartline': 2,...
# 2  [{'consoleendline': 70, 'consolestartline': 0,...
# 3  [{'consoleendline': 102, 'consolestartline': 1...
# 4  [{'consoleendline': 112, 'consolestartline': 0...
#
#                        _rid  \
# 0  ipJnAMvHpvRXJgAAAAAAAA==
# 1  ipJnAMvHpvRYJgAAAAAAAA==
# 2  ipJnAMvHpvRZJgAAAAAAAA==
# 3  ipJnAMvHpvRaJgAAAAAAAA==
# 4  ipJnAMvHpvRbJgAAAAAAAA==
#
#                                                _self  \
# 0  dbs/ipJnAA==/colls/ipJnAMvHpvQ=/docs/ipJnAMvHp...
# 1  dbs/ipJnAA==/colls/ipJnAMvHpvQ=/docs/ipJnAMvHp...
# 2  dbs/ipJnAA==/colls/ipJnAMvHpvQ=/docs/ipJnAMvHp...
# 3  dbs/ipJnAA==/colls/ipJnAMvHpvQ=/docs/ipJnAMvHp...
# 4  dbs/ipJnAA==/colls/ipJnAMvHpvQ=/docs/ipJnAMvHp...
#
#                                     _etag  _attachments         _ts  \
# 0  "0100be16-0000-3c00-0000-673ade660000"  attachments/  1731911270
# 1  "01005917-0000-3c00-0000-673ae0090000"  attachments/  1731911689
# 2  "01007018-0000-3c00-0000-673ae2dc0000"  attachments/  1731912412
# 3  "0100ba18-0000-3c00-0000-673ae3910000"  attachments/  1731912593
# 4  "0100bc18-0000-3c00-0000-673ae3b20000"  attachments/  1731912626
#
#   expected_duration
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#
# [5 rows x 23 columns]

# %%
df.shape
# Out:
# (1709, 23)
